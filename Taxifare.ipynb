# %%
import pandas as pd

# Sample taxi trip data
data = {
    'Trip_Duration_Minutes': [5, 12, 8, 15, 22, 9, 3, 14, 30, 7],
    'Trip_Distance_Miles': [1.2, 3.5, 2.1, 4.3, 6.5, 2.7, 0.9, 4.0, 8.2, 1.8],
    'Fare_Amount': [7.5, 12.0, 9.0, 15.5, 22.0, 10.0, 6.0, 14.0, 28.0, 8.5]
}

df = pd.DataFrame(data)

# Save to CSV
df.to_csv('taxi_fare_data.csv', index=False)

print("✅ taxi_fare_data.csv created!")
df.head()
# Out:
# ✅ taxi_fare_data.csv created!
#    Trip_Duration_Minutes  Trip_Distance_Miles  Fare_Amount
# 0                      5                  1.2          7.5
# 1                     12                  3.5         12.0
# 2                      8                  2.1          9.0
# 3                     15                  4.3         15.5
# 4                     22                  6.5         22.0
